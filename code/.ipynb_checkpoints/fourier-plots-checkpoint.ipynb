# %%
import matplotlib.pyplot as plt
import numpy as np
import csv
import os
# %matplotlib inline

# %%
def readValues(filename):
    values = []
    with open(filename) as csvfile:
        next(csvfile) #skip header
        reader = csv.reader(csvfile, delimiter=' ')
        for row in reader:
            values = [float(element) for element in row]
    return(values)

# %%
def readValues_modified(filename):
    values = []
    with open(filename) as csvfile:
        next(csvfile) #skip header
        reader = csv.reader(csvfile, delimiter=' ')
        for element in reader:
            values.append(float(element[0]))
    return(values)

# %%
def get_dirs_list(directory):
    subdirs = next(os.walk(directory))[1]
    dirs = []
    for subdir in subdirs:
        #vsg = subdir[4:-18]
        #dirs.append((vsg, directory + subdir + '/data.csv'))
        dirs.append(directory + subdir + '/data.csv')
    return(sorted(dirs))

# %%
def get_dirs(directory):
    subdirs = next(os.walk(directory))[1]
    for subdir in subdirs:
        vsg = subdir[4:-18]
        yield((vsg, directory + subdir + '/data.csv'))

# %%
def read_imag_values(file):
    result = []
    with open(file) as csvfile:
        reader = csv.reader(csvfile, delimiter=' ')
        for row in reader:
            result.append([float(element) for element in row])
    return(result)

# %%
def transform_to_density(magnetic_field):
    phi0 = 2.067e-15 #in T*m**2
    L = 1.0e-6 #in m,total length, including London
    
    for index, b in enumerate(magnetic_field):
        
        
    
    return

# %%
def transform_to_density_test(B, Ic, x_values):
    phi0 = 2.067e-15 #in T*m**2
    L = 0.3e-6 #in m,total length, including London
    omega = 2 * np.pi * L / phi0
    dB = B[1] - B[0]
    real, imag = Ic
    
    Jx_values = []
    for x in x_values:
        Jx_real = 0
        Jx_imag = 0
        for k, b in enumerate(B):
            Ic_real = real[k] #Fourier coefficient
            Ic_imag = imag[k]
            Jx_real += (Ic_real * np.cos(omega * b * x) - Ic_imag * np.sin(omega * b * x)) * dB 
            Jx_imag += (Ic_imag * np.cos(omega * b * x) + Ic_real * np.sin(omega * b * x)) * dB
        Jx_abs = np.sqrt(Jx_real**2 + Jx_imag**2)
        Jx_values.append(Jx_abs)
    return(Jx_values)

# %%
testfile = '/home/nefta/thesis/code/testdata.csv'

# %%
values = np.asarray(read_imag_values(testfile)).T

# %%
fig, ax = plt.subplots(figsize=(16,9))
for index in range(len(values)):
    ax.plot(values[index], label=index, linestyle='none', marker='o')
ax.legend()

# %%
abs_val, real_val, imag_val = values

# %%
plt.plot(real_val)

# %%
len(values[0])
# Out:
# 500

# %%
maxB = 9e-05
magnetic_field = np.linspace(-maxB, maxB, 200)
max_x = 1
x = np.linspace(-max_x, max_x, 500)
#len(transform_to_density_test(B=magnetic_field, Ic=values[1], x_values=x))
fig, ax = plt.subplots(figsize=(16, 9))
density =  transform_to_density_test(B=magnetic_field, Ic=(values[1], values[2]), x_values=x)
ax.plot(x, density, linestyle='none', marker='o')

# %% [markdown]
# # Supercurrent Plots

# %% [markdown]
# #### plots for experiment3, short channel

# %%
directory = '/home/nefta/thesis/results/wg3_2/supercurrent/'

# %%
maxB = 9e-05
mag_field = np.linspace(-maxB, maxB, 500)

# %%
fig = plt.figure(figsize=(16, 9))
for i, label in enumerate(('a', 'b', 'c', 'd', 'e', 'f',)):
    offset = 0
    n = 321 + i
    ax = fig.add_subplot(n)
    files = get_dirs_list(directory)[2:]
    current_values = readValues(files[i + offset ][1])
    ax.plot(mag_field, current_values, linestyle='None',
             marker='.', label=r'$\varphi_{{SG}} = {0}$'.format(files[i + offset][0]))
    ax.grid()
    ax.legend(loc=1)
    ax.set_xlabel(r'$B$', fontsize=12)
    ax.set_ylabel(r'$I_c$', fontsize=12)
    ax.ticklabel_format(style='sci')

# %%
fig = plt.figure(figsize=(16, 9))
for i, label in enumerate(('a', 'b', 'c', 'd', 'e', 'f',)):
    offset = 5
    n = 321 + i
    ax = fig.add_subplot(n)
    files = get_dirs_list(directory)[2:]
    current_values = readValues(files[i + offset ][1])
    ax.plot(mag_field, current_values, linestyle='None',
             marker='.', label=r'$\varphi_{{SG}} = {0}$'.format(files[i + offset][0]))
    ax.grid()
    ax.legend(loc=1)
    ax.set_xlabel(r'$B$', fontsize=12)
    ax.set_ylabel(r'$I_c$', fontsize=12)
    ax.ticklabel_format(style='sci')

# %% [markdown]
# #### plots for experiment 3, long channel

# %%
directory = '/home/nefta/thesis/results/wg3_1_small/supercurrent/new/'

# %%
maxB = 9e-05
mag_field = np.linspace(-maxB, maxB, 500)

# %%
fig = plt.figure(figsize=(16, 9))
for i, label in enumerate(('a', 'b', 'c', 'd', 'e', 'f',)):
    offset = 0
    n = 321 + i
    ax = fig.add_subplot(n)
    files = get_dirs_list(directory)[1:]
    current_values = readValues(files[i + offset ][1])
    ax.plot(mag_field, current_values, linestyle='None',
             marker='.', label=r'$\varphi_{{SG}} = {0}$'.format(files[i + offset][0]))
    ax.grid()
    ax.legend(loc=1)
    ax.set_xlabel(r'$B$', fontsize=12)
    ax.set_ylabel(r'$I_c$', fontsize=12)
    ax.ticklabel_format(style='sci')

# %%
fig = plt.figure(figsize=(16, 9))
for i, label in enumerate(('a', 'b', 'c', 'd', 'e', 'f',)):
    offset = 6
    n = 321 + i
    ax = fig.add_subplot(n)
    files = get_dirs_list(directory)
    current_values = readValues(files[i + offset ][1])
    ax.plot(mag_field, current_values, linestyle='None',
             marker='.', label=r'$\varphi_{{SG}} = {0}$'.format(files[i + offset][0]))
    ax.grid()
    ax.legend(loc=1)
    ax.set_xlabel(r'$B$', fontsize=12)
    ax.set_ylabel(r'$I_c$', fontsize=12)
    ax.ticklabel_format(style='sci')
